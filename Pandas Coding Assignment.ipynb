# %% [markdown]
# # Pandas for Data Wrangling Assignment
# ## Introduction
# This coding assignment is designed to get you familiarized with essential Pandas operations for data wrangling. No matter what data you're working with, these tools will come in handy.

# %% [markdown]
# ## Background
# For the purpose of this assignment, imagine you are a data analyst for BearBNB, a vacation rental company. They've tasked you with handling different aspects of development in San Francisco, and supply you with datasets on listings and ratings of each their properties in the area.

# %% [markdown]
# ## Setting up
# Running the following cell will allow us to use the most commonly used libraries that we are going to use for Data Analysis. The line `%matplotlib inline` allows us to show the graph after running a cell in which we plot a graph. That comes in really handy and is one of the powerful tools of Jupyter.

# %%
import pandas as pd
import numpy as np
import zipfile
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %% [markdown]
# ### Shortcuts

# %% [markdown]
# Even if you are familiar with Jupyter, you are strongly encouraged to become proficient with keyboard shortcuts (this will save you time in the future). To learn about keyboard shortcuts, go to **Help --> Keyboard Shortcuts** in the menu above.
#
# Here are a few that we like:
# 1. `Ctrl` + `Return` : *Evaluate the current cell*
# 1. `Shift` + `Return`: *Evaluate the current cell and move to the next*
# 1. `ESC` : *command mode* (may need to press before using any of the commands below)
# 1. `a` : *create a cell above*
# 1. `b` : *create a cell below*
# 1. `dd` : *delete a cell*
# 1. `z` : *undo the last cell operation*
# 1. `m` : *convert a cell to markdown*
# 1. `y` : *convert a cell to code*

# %% [markdown]
# ##  Importing and cleaning raw data
# A csv file is a delimited text file that's separated by commas. A Pandas dataframe is the main data structure you'll be working with, a dict-like container for Series objects (one-dimensional ndarrays with axis labels).

# %% [markdown]
# **Question 1.1** Using read_csv, load the ratings and listings csv files into Pandas dataframes and show the first ten lines of each.

# %%
listings = pd.read_csv("listings.csv")
ratings = pd.read_csv("ratings.csv")
#TODO: Display the first 10 lines of listings

### start code ###
listings.head(10)
### end code ###
# Out:
#       id                                               name  host_id  \
# 0    958              Bright, Modern Garden Unit - 1BR/1BTH     1169
# 1   5858                                 Creative Sanctuary     8904
# 2   7918         A Friendly Room - UCSF/USF - San Francisco    21994
# 3   8014      Newly Remodeled room in big house WIFI market    22402
# 4   8142  Friendly Room Apt. Style -UCSF/USF - San Franc...    21994
# 5   8339                    Historic Alamo Square Victorian    24215
# 6   8739                Mission Sunshine, with Private Bath     7149
# 7  10251                   Victorian Suite in Inner Mission    35199
# 8  10578                Classic Nob Hill Studio - Roof Deck    37049
# 9  10820                 Haight Buena Vista Park Garden 3BR    38836
#
#           host_name  neighbourhood_group     neighbourhood  latitude  \
# 0             Holly                  NaN  Western Addition  37.76931
# 1  Philip And Tania                  NaN    Bernal Heights  37.74511
# 2             Aaron                  NaN    Haight Ashbury  37.76555
# 3               Jia                  NaN     Outer Mission  37.73075
# 4             Aaron                  NaN    Haight Ashbury  37.76555
# 5              Rosy                  NaN  Western Addition  37.77525
# 6      Ivan & Wendy                  NaN           Mission  37.76030
# 7     Roman & Sarah                  NaN           Mission  37.75831
# 8            Andrew                  NaN          Nob Hill  37.79143
# 9            Bernat                  NaN    Haight Ashbury  37.77187
#
#    longitude        room_type  price  minimum_nights  number_of_reviews  \
# 0 -122.43386  Entire home/apt    131               2                262
# 1 -122.42102  Entire home/apt    235              30                111
# 2 -122.45213     Private room     56              32                 19
# 3 -122.44841     Private room     45               5                 85
# 4 -122.45213     Private room     56              32                  8
# 5 -122.43637  Entire home/apt    743               5                 28
# 6 -122.42197     Private room    169               1                736
# 7 -122.41386  Entire home/apt    200              30                337
# 8 -122.41544  Entire home/apt    120              30                 18
# 9 -122.43859  Entire home/apt    170              30                 37
#
#   last_review  reviews_per_month  calculated_host_listings_count  \
# 0  2020-09-16               1.92                               1
# 1  2017-08-06               0.80                               1
# 2  2020-03-06               0.14                               9
# 3  2018-10-01               0.85                               2
# 4  2018-09-12               0.11                               9
# 5  2019-06-28               0.21                               2
# 6  2020-03-16               5.41                               2
# 7  2019-05-27               2.50                               1
# 8  2015-05-17               0.17                               1
# 9  2018-12-01               0.28                              38
#
#    availability_365      neighborhood
# 0               206  Western Addition
# 1               365    Bernal Heights
# 2               365    Haight Ashbury
# 3                45     Outer Mission
# 4               365    Haight Ashbury
# 5                 0  Western Addition
# 6               179           Mission
# 7               365           Mission
# 8               364          Nob Hill
# 9                73    Haight Ashbury

# %%
#TODO: Display the first 10 lines of ratings

### start code ###
ratings.head(10)
### end code ###
# Out:
#    listing_id        date  rating
# 0         958  2009-07-23      83
# 1         958  2009-08-03      94
# 2         958  2009-09-27      74
# 3         958  2009-11-05      89
# 4         958  2010-02-13      69
# 5         958  2010-03-13      98
# 6         958  2010-04-03      74
# 7         958  2011-04-08      79
# 8         958  2011-09-26      90
# 9         958  2012-07-24      93

# %% [markdown]
# <details>
#     <summary>Solution</summary>
#
#     listings = pd.read_csv("listings.csv")
#     ratings = pd.read_csv("ratings.csv")
#
#     listings.head(10)
#     ratings.head(10)
# </details>

# %% [markdown]
# **Question 1.2** What are the data types for each of the columns in listings?

# %%
#TODO: Display the data types of each column in each dataset

### start code ###
listings.dtypes

### end code ###
# Out:
# id                                  int64
# name                               object
# host_id                             int64
# host_name                          object
# neighbourhood_group               float64
# neighbourhood                      object
# latitude                          float64
# longitude                         float64
# room_type                          object
# price                               int64
# minimum_nights                      int64
# number_of_reviews                   int64
# last_review                        object
# reviews_per_month                 float64
# calculated_host_listings_count      int64
# availability_365                    int64
# neighborhood                       object
# dtype: object

# %% [markdown]
# <details>
#     <summary>Solution</summary>
#
#     listings.dtypes
# </details>

# %% [markdown]
# **Question 1.3** Generate descriptive statistics of all the columns (not just numerical) in listings.
#
# *Hint: Pandas already provides a function for doing this for numerical data by default.*

# %%
#TODO: Display descriptive statistics for each column in listings

### start code ###
listings.describe(include='all')

### end code ###
# Out:
#                   id                           name       host_id   host_name  \
# count   6.998000e+03                           6998  6.998000e+03        6998
# unique           NaN                           6664           NaN        1991
# top              NaN  Union Square Convention Hotel           NaN  Blueground
# freq             NaN                             40           NaN         182
# mean    2.317998e+07                            NaN  6.642734e+07         NaN
# std     1.446705e+07                            NaN  8.927933e+07         NaN
# min     9.580000e+02                            NaN  4.700000e+02         NaN
# 25%     9.854103e+06                            NaN  4.352266e+06         NaN
# 50%     2.371341e+07                            NaN  2.089914e+07         NaN
# 75%     3.620138e+07                            NaN  1.033522e+08         NaN
# max     4.572391e+07                            NaN  3.706269e+08         NaN
#
#         neighbourhood_group          neighbourhood     latitude    longitude  \
# count                   0.0                   6998  6998.000000  6998.000000
# unique                  NaN                     36          NaN          NaN
# top                     NaN  Downtown/Civic Center          NaN          NaN
# freq                    NaN                    711          NaN          NaN
# mean                    NaN                    NaN    37.767180  -122.429816
# std                     NaN                    NaN     0.022968     0.027165
# min                     NaN                    NaN    37.708250  -122.511630
# 25%                     NaN                    NaN    37.752032  -122.442588
# 50%                     NaN                    NaN    37.769980  -122.423990
# 75%                     NaN                    NaN    37.786758  -122.409982
# max                     NaN                    NaN    37.810310  -122.368570
#
#               room_type         price  minimum_nights  number_of_reviews  \
# count              6998   6998.000000    6.998000e+03        6998.000000
# unique                4           NaN             NaN                NaN
# top     Entire home/apt           NaN             NaN                NaN
# freq               4244           NaN             NaN                NaN
# mean                NaN    260.552729    1.430807e+04          45.229637
# std                 NaN    895.737694    1.195399e+06          82.593117
# min                 NaN     10.000000    1.000000e+00           0.000000
# 25%                 NaN     89.000000    2.000000e+00           1.000000
# 50%                 NaN    140.000000    7.000000e+00           9.000000
# 75%                 NaN    229.000000    3.000000e+01          50.000000
# max                 NaN  25000.000000    1.000000e+08         821.000000
#
#        last_review  reviews_per_month  calculated_host_listings_count  \
# count         5441        5441.000000                     6998.000000
# unique        1032                NaN                             NaN
# top     2020-02-28                NaN                             NaN
# freq           113                NaN                             NaN
# mean           NaN           1.327851                       16.009145
# std            NaN           1.659870                       37.609985
# min            NaN           0.010000                        1.000000
# 25%            NaN           0.190000                        1.000000
# 50%            NaN           0.650000                        2.000000
# 75%            NaN           1.860000                        9.000000
# max            NaN          20.430000                      182.000000
#
#         availability_365           neighborhood
# count        6998.000000                   6998
# unique               NaN                     36
# top                  NaN  Downtown/Civic Center
# freq                 NaN                    711
# mean          153.367819                    NaN
# std           141.414355                    NaN
# min             0.000000                    NaN
# 25%             0.000000                    NaN
# 50%           113.000000                    NaN
# 75%           305.000000                    NaN
# max           365.000000                    NaN

# %% [markdown]
# <details>
#     <summary>Solution</summary>
#
#     listings.describe(include='all')
# </details>

# %% [markdown]
# **Question 1.4** Is there a difference in the statistics that you observe for numerical versus categorical columns? Write your observations in the box below.

# %% [markdown]
# <details>
#     <summary>Solution</summary>
#
#     For numeric data, we include count, mean, std, min, max as well as lower, 50 and upper percentiles.
#     For categorical data, we include count, unique, top, and freq.
# </details>

# %% [markdown]
# ## Data Cleaning

# %% [markdown]
# **Question 2.1** Firstly, we need to handle missing data. Implement a function that takes a dataframe object and counts the percentage of nulls in each of the columns.

# %%
def null_percentage(df):
    """
    Calculates the percentage of null values in a dataframe.
    
    args:
      df: dataframe object
                      
    returns:
      percent_missing: Series object containing each column's null percentage
      
    """
    #TODO: calculate the missing percentage for each column
    ### start code ###
    percent_missing = df.isnull().sum() * 100 / len(df)
    ### end code ###
    return percent_missing

# %% [markdown]
# <details>
#     <summary>Solution</summary>
#
#     percent_missing = df.isnull().sum() * 100 / len(df)
# </details>

# %% [markdown]
# Now let's display the percentage of nulls for listings and ratings.

# %%
listings_null = null_percentage(listings)
listings_null
# Out:
# id                                  0.000000
# name                                0.000000
# host_id                             0.000000
# host_name                           0.000000
# neighbourhood_group               100.000000
# neighbourhood                       0.000000
# latitude                            0.000000
# longitude                           0.000000
# room_type                           0.000000
# price                               0.000000
# minimum_nights                      0.000000
# number_of_reviews                   0.000000
# last_review                        22.249214
# reviews_per_month                  22.249214
# calculated_host_listings_count      0.000000
# availability_365                    0.000000
# neighborhood                        0.000000
# dtype: float64

# %%
ratings_null = null_percentage(ratings)
ratings_null
# Out:
# listing_id    0.0
# date          0.0
# rating        0.0
# dtype: float64

# %% [markdown]
# **Question 2.2** We need to handle missing data before performing any analysis since null values can skew the distribution of the features. To do this, you need to find a reasonable method of replacing or removing NaN values. In the boxes below, remove the null values and provide justification as to why the method you chose is reasonable.

# %%
#TODO: handle null values in listings
### start code ###

listings.drop(columns=['neighbourhood_group'], inplace=True)
listings.dropna(inplace=True)
### end code ###
# Out:
# id                                0
# name                              0
# host_id                           0
# host_name                         0
# neighbourhood                     0
# latitude                          0
# longitude                         0
# room_type                         0
# price                             0
# minimum_nights                    0
# number_of_reviews                 0
# last_review                       0
# reviews_per_month                 0
# calculated_host_listings_count    0
# availability_365                  0
# neighborhood                      0
# dtype: int64

# %% [markdown]
# <details>
#     <summary>Sample Solution</summary>
#
#     listings.drop(columns=['neighbourhood_group'], inplace=True)
#     listings.dropna(inplace=True)
# </details>

# %% [markdown]
# Write your justifications below.

# %% [markdown]
# <details>
#     <summary>Sample Solution</summary>
#
#     We drop the column that's entirely null since it won't be useful at all.
#     If we look at the percentages of nulls in reviews per month and last review, they're exactly the same. This could indicate that they're missing data at the same records, a simple scan of these rows will confirm this. These rows will not be useful since they won't contain any information in the ratings dataset (missing or no reviews of the property). Thus we drop the rows with null values in either of these columns.
# </details>

# %% [markdown]
# ### Identifying Outliers
# Determining outliers is one of the biggest challenges in cleaning data, but the performance of machine learning algorithms will be heavily affected if they aren't removed. The following section will focus on introducing different methods of identifying these data points.

# %% [markdown]
# **Question 3.1** As you are probably familiar with, the interquartile range can be used to measure statistical dispersion. Calculate the IQR of each of the numerical columns in `listings`.

# %%
#TODO: Determine the IQR for each column in listings
### start code ###
Q1 = listings.quantile(0.25) 
Q3 = listings.quantile(0.75) 
IQR = Q3 - Q1 
print(IQR)

### end code ###
# Out:
# id                                2.418216e+07
# host_id                           6.752641e+07
# latitude                          3.582000e-02
# longitude                         3.377000e-02
# price                             1.390000e+02
# minimum_nights                    2.800000e+01
# number_of_reviews                 7.100000e+01
# reviews_per_month                 1.670000e+00
# calculated_host_listings_count    4.000000e+00
# availability_365                  2.800000e+02
# dtype: float64

# %% [markdown]
# <details>
#     <summary>Solution</summary>
#     Q1 = listings.quantile(0.25)
#     Q3 = listings.quantile(0.75)
#     IQR = Q3 - Q1
#     print(IQR)
#
# </details>

# %% [markdown]
# **Question 3.2** Create a box plot to visualize each of the IQRs you've calculated above.

# %%
#TODO: Create a box plot for listings
### start code ###
plt.boxplot(listings["price"])

### end code ###
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1303eda30>,
#   <matplotlib.lines.Line2D at 0x130405160>],
#  'caps': [<matplotlib.lines.Line2D at 0x1304056a0>,
#   <matplotlib.lines.Line2D at 0x1304056d0>],
#  'boxes': [<matplotlib.lines.Line2D at 0x1303edd00>],
#  'medians': [<matplotlib.lines.Line2D at 0x1304051f0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x131049730>],
#  'means': []}
